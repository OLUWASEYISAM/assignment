# %%
import pandas as pd

# %%
df = pd.read_csv("HAMOYE first assignment.csv", encoding= "latin-1")

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
#Percentage of missing data in 2014
(1589/59354)*100
# Out:
# 2.6771573946153584

# %%
#minimum value of Element code
df['Element Code'].min()
# Out:
# 511

# %%
#Getting the year that has the minimum value of Element code(511)
print(511 in df['Y2014'].values)
print(511 in df['Y2015'].values)
print(511 in df['Y2016'].values)
print(511 in df['Y2017'].values)
# Out:
# True
# False
# True
# True

# %%
#groupby operation on Elements
df.groupby("Element")["Y2017"].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
i = [[35, 'Portugal', 94],[33, 'Argentina', 93], [30, 'Brazil', 92]]
col = ['Age', 'Nationality', 'Overall']
pd.DataFrame(i, columns= col, index = [1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
import numpy as np
array = np.array([[94,89,63],[93,92,48],[92,94,56]])
print(array[:1,1:])
print(array[1,:])
print(array[:2,1:])
print(array[:2,0:])
# Out:
# [[89 63]]
# [93 92 48]
# [[89 63]
#  [92 48]]
# [[94 89 63]
#  [93 92 48]]

# %%
y = [(2,4),(7,8),(1,5,9)]
x = y[1][1]
x
# Out:
# 8

# %%
df.groupby("Area")["Y2017"].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
df.groupby("Item")["Y2015"].sum()
# Out:
# Item
# Alcohol, Non-Food        2180.00
# Alcoholic Beverages     98783.72
# Animal Products         11811.73
# Animal fats            200675.72
# Apples and products     10559.15
#                          ...
# Vegetables, Other      158104.08
# Vegetal Products       107064.17
# Wheat and products     234710.51
# Wine                     4251.81
# Yams                   203151.78
# Name: Y2015, Length: 119, dtype: float64

# %%
df.groupby("Item")["Y2018"].sum()
# Out:
# Item
# Alcohol, Non-Food        2293.00
# Alcoholic Beverages     97847.27
# Animal Products         11578.61
# Animal fats            269648.27
# Apples and products      9640.51
#                          ...
# Vegetables, Other      163987.21
# Vegetal Products       107775.39
# Wheat and products     242645.19
# Wine                     4039.32
# Yams                   221272.09
# Name: Y2018, Length: 119, dtype: float64

# %%
#Unique countries
len(df['Area'].unique())
# Out:
# 49

# %%
#Getting the index of Madagascar
df[df['Area'] == 'Madagascar'].index
# Out:
# Int64Index([30715, 30716, 30717, 30718, 30719, 30720, 30721, 30722, 30723,
#             30724,
#             ...
#             32144, 32145, 32146, 32147, 32148, 32149, 32150, 32151, 32152,
#             32153],
#            dtype='int64', length=1439)

# %%
#df2 becomes data for Madagascar
df2 = df[30715:32153].reset_index()

# %%
df2
# Out:
#       index  Area Code        Area  Item Code           Item  Element Code  \
# 0     30715        129  Madagascar       2501     Population           511
# 1     30716        129  Madagascar       2501     Population          5301
# 2     30717        129  Madagascar       2901    Grand Total           664
# 3     30718        129  Madagascar       2901    Grand Total           674
# 4     30719        129  Madagascar       2901    Grand Total           684
# ...     ...        ...         ...        ...            ...           ...
# 1433  32148        129  Madagascar       2899  Miscellaneous          5170
# 1434  32149        129  Madagascar       2899  Miscellaneous          5142
# 1435  32150        129  Madagascar       2899  Miscellaneous           645
# 1436  32151        129  Madagascar       2899  Miscellaneous           664
# 1437  32152        129  Madagascar       2899  Miscellaneous           674
#
# ...

# %%
df2.groupby("Element")["Y2015"].sum()
# Out:
# Element
# Domestic supply quantity                  31214.98
# Export Quantity                             494.75
# Fat supply quantity (g/capita/day)           91.84
# Feed                                       2070.22
# Food                                      21120.65
# Food supply (kcal/capita/day)              7685.00
# Food supply quantity (kg/capita/yr)         871.59
# Import Quantity                            1721.80
# Losses                                     2176.00
# Other uses (non-food)                      3957.12
# Processing                                 1803.00
# Production                                29482.89
# Protein supply quantity (g/capita/day)      173.05
# Residuals                                  -616.00
# Seed                                        699.00
# Stock Variation                            -505.00
# Total Population - Both sexes             24234.00
# Name: Y2015, dtype: float64

# %%
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %%
df.shape
# Out:
# (60943, 12)

# %%
df.groupby("Area")["Y2017"].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
my_tuppy = (1,2,5,8)
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8404\3506354595.py in <module>
#       1 my_tuppy = (1,2,5,8)
# ----> 2 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
df2.groupby("Element").sum()
# Out:
#                                           index  Area Code  Item Code  \
# Element
# Domestic supply quantity                3743186      15351     318888
# Export Quantity                         3272658      13416     279445
# Fat supply quantity (g/capita/day)      3460782      14190     296506
# Feed                                    1092115       4515      94030
# Food                                    3463065      14190     295817
# Food supply (kcal/capita/day)           3492713      14319     299405
# Food supply quantity (kg/capita/yr)     3463175      14190     295817
# Import Quantity                         3493699      14319     297945
# Losses                                  1723484       7095     148102
# Other uses (non-food)                   1606352       6579     138246
# Processing                              2379024       9804     201929
# Production                              3459797      14190     295071
# ...
